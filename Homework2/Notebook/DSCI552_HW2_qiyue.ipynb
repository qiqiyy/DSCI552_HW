# %% [markdown]
# #### Name: Qi Yue USC ID: 5081825219

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### (b) Exploring the data:

# %% [markdown]
# i. How many rows are in this data set? How many columns? What do the rows
# and columns represent?

# %% [markdown]
# ii. Make pairwise scatterplots of all the varianbles in the data set including the
# predictors (independent variables) with the dependent variable. Describe
# your findings.

# %% [markdown]
# iii. What are the mean, the median, range, first and third quartiles, and interquartile ranges of each of the variables in the dataset? Summarize them
# in a table.

# %%
# import dataset
data = pd.read_excel('../Data/CCPP/Folds5x2_pp.xlsx')
data
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %% [markdown]
# For the dataset, there are 9569 rows and 5 columns. Each column represents one feature value in each sample and each row represents one sample.

# %%
# Create the pairwise scatterplots
pairplot_fig = sns.pairplot(data)
plt.subplots_adjust(top=0.9)
pairplot_fig.fig.suptitle("Pairwise Scatter plots of all the varianbles in the Combined Cycle Power Plant dataset", fontsize=18, alpha=0.9, weight='bold')
plt.show()

# %%
# Calculate the mean, the median, range, first and third quartiles, and interquartile ranges of AT
data_AT = data['AT']
data_AT_mean = data_AT.mean(axis=0)
data_AT_median = data_AT.median(axis=0)
data_AT_min = data_AT.min(axis=0)
data_AT_max = data_AT.max(axis=0)
data_AT_quartile1 = data_AT.quantile([0.25])
data_AT_quartile2 = data_AT.quantile([0.75])
data_AT_interquartile = data_AT_quartile2[0.75] - data_AT_quartile1[0.25]

table1 = {'Mean' : data_AT_mean, 'Median' : data_AT_median, 'Min': data_AT_min, 'Max': data_AT_max, 'First quartile': data_AT_quartile1[0.25], 'Third quartile': data_AT_quartile2[0.75], 'Interquartile': data_AT_interquartile }
#dataf1 = pd.Series(table1).to_frame('AT')
dataf1 = pd.DataFrame([table1])
dataf1
# Out:
#         Mean  Median   Min    Max  First quartile  Third quartile  \
# 0  19.651231  20.345  1.81  37.11           13.51           25.72
#
#    Interquartile
# 0          12.21

# %%
# Calculate the mean, the median, range, first and third quartiles, and interquartile ranges of Exhaust Vacuum (V)
data_V = data['V']
data_V_mean = data_V.mean(axis=0)
data_V_median = data_V.median(axis=0)
data_V_min = data_V.min(axis=0)
data_V_max = data_V.max(axis=0)
data_V_quartile1 = data_V.quantile([0.25])
data_V_quartile2 = data_V.quantile([0.75])
data_V_interquartile = data_V_quartile2[0.75] - data_V_quartile1[0.25]

table2 = {'Mean' : data_V_mean, 'Median' : data_V_median, 'Min': data_V_min, 'Max': data_V_max, 'First quartile': data_V_quartile1[0.25], 'Third quartile': data_V_quartile2[0.75], 'Interquartile': data_V_interquartile }
#dataf2 = pd.Series(table2).to_frame('V')
dataf2 = pd.DataFrame([table2])
dataf2
# Out:
#         Mean  Median    Min    Max  First quartile  Third quartile  \
# 0  54.305804   52.08  25.36  81.56           41.74           66.54
#
#    Interquartile
# 0           24.8

# %%
# Calculate the mean, the median, range, first and third quartiles, and interquartile ranges of Ambient Pressure (AP)
data_AP = data['AP']
data_AP_mean = data_AP.mean(axis=0)
data_AP_median = data_AP.median(axis=0)
data_AP_min = data_AP.min(axis=0)
data_AP_max = data_AP.max(axis=0)
data_AP_quartile1 = data_AP.quantile([0.25])
data_AP_quartile2 = data_AP.quantile([0.75])
data_AP_interquartile = data_AP_quartile2[0.75] - data_AP_quartile1[0.25]

table3 = {'Mean' : data_AP_mean, 'Median' : data_AP_median, 'Min': data_AP_min, 'Max': data_AP_max, 'First quartile': data_AP_quartile1[0.25], 'Third quartile': data_AP_quartile2[0.75], 'Interquartile': data_AP_interquartile }
#dataf3 = pd.Series(table3).to_frame('AP')
dataf3 = pd.DataFrame([table3])
dataf3
# Out:
#           Mean   Median     Min     Max  First quartile  Third quartile  \
# 0  1013.259078  1012.94  992.89  1033.3          1009.1         1017.26
#
#    Interquartile
# 0           8.16

# %%
# Calculate the mean, the median, range, first and third quartiles, and interquartile ranges of Relative Humidity (RH)
data_RH = data['RH']
data_RH_mean = data_RH.mean(axis=0)
data_RH_median = data_RH.median(axis=0)
data_RH_min = data_RH.min(axis=0)
data_RH_max = data_RH.max(axis=0)
data_RH_quartile1 = data_RH.quantile([0.25])
data_RH_quartile2 = data_RH.quantile([0.75])
data_RH_interquartile = data_RH_quartile2[0.75] - data_RH_quartile1[0.25]

table4 = {'Mean' : data_RH_mean, 'Median' : data_RH_median, 'Min': data_RH_min, 'Max': data_RH_max, 'First quartile': data_RH_quartile1[0.25], 'Third quartile': data_RH_quartile2[0.75], 'Interquartile': data_RH_interquartile }
#dataf4 = pd.Series(table4).to_frame('RH')
dataf4 = pd.DataFrame([table4])
dataf4
# Out:
#         Mean  Median    Min     Max  First quartile  Third quartile  \
# 0  73.308978  74.975  25.56  100.16         63.3275           84.83
#
#    Interquartile
# 0        21.5025

# %%
# Calculate the mean, the median, range, first and third quartiles, and interquartile ranges of net hourly electrical energy output (EP)
data_PE = data['PE']
data_PE_mean = data_PE.mean(axis=0)
data_PE_median = data_PE.median(axis=0)
data_PE_min = data_PE.min(axis=0)
data_PE_max = data_PE.max(axis=0)
data_PE_quartile1 = data_PE.quantile([0.25])
data_PE_quartile2 = data_PE.quantile([0.75])
data_PE_interquartile = data_PE_quartile2[0.75] - data_PE_quartile1[0.25]

table5 = {'Mean' : data_PE_mean, 'Median' : data_PE_median, 'Min': data_PE_min, 'Max': data_PE_max, 'First quartile': data_PE_quartile1[0.25], 'Third quartile': data_PE_quartile2[0.75], 'Interquartile': data_PE_interquartile }
#dataf5 = pd.Series(table5).to_frame('PE')
dataf5 = pd.DataFrame([table5])
dataf5
# Out:
#          Mean  Median     Min     Max  First quartile  Third quartile  \
# 0  454.365009  451.55  420.26  495.76          439.75          468.43
#
#    Interquartile
# 0          28.68

# %% [markdown]
# #### (c) For each predictor, fit a simple linear regression model to predict the response.
# Describe your results. In which of the models is there a statistically significant
# association between the predictor and the response? Create some plots to back
# up your assertions. Are there any outliers that you would like to remove from
# your data for each of these regression tasks?

# %%
# A linear regression model for AT and PE
import statsmodels.api as sm
X1 = data.loc[:, ['AT']]
y = data.loc[:, ['PE']]
X1 = sm.add_constant(X1)
# Fit and summarize OLS model
mod1 = sm.OLS(y, X1)
res1 = mod1.fit()
#stud_res1 = res1.outlier_test()
print(res1.summary())
#print(stud_res1)
#print(res1.pvalues)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.899
# Method:                 Least Squares   F-statistic:                 8.510e+04
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):               0.00
# Time:                        16:28:03   Log-Likelihood:                -29756.
# No. Observations:                9568   AIC:                         5.952e+04
# Df Residuals:                    9566   BIC:                         5.953e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        497.0341      0.156   3177.280      0.000     496.727     497.341
# ...

# %%
#outlier1 = stud_res1[abs(stud_res1['student_resid']) > 3 ].size
#outlier1

# %%
influence1 = res1.get_influence()
cooks1 = influence1.cooks_distance
num1 = np.sum(cooks1[0] > 4/9568)
print("The number of outliers for 'AT' model is", num1, '.')
# Out:
# The number of outliers for 'AT' model is 416 .

# %%
from sklearn.linear_model import LinearRegression
liregr = LinearRegression()
liregr.fit(X1, y)
pred1 = liregr.predict(X1)

# Create scatter plot
plt.scatter(X1.iloc[:,1].values, y)
plt.plot(X1.iloc[:,1].values, pred1,c='r')
plt.xlabel('AT')
plt.ylabel('PE')
plt.show()

# %%
# A linear regression model for V and PE
X2 = data.loc[:, ['V']]
y = data.loc[:, ['PE']]
X2 = sm.add_constant(X2)
# Fit and summarize OLS model
mod2 = sm.OLS(y, X2)
res2 = mod2.fit()
print(res2.summary())
#print(res2.pvalues)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.757
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                 2.972e+04
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):               0.00
# Time:                        16:28:03   Log-Likelihood:                -33963.
# No. Observations:                9568   AIC:                         6.793e+04
# Df Residuals:                    9566   BIC:                         6.794e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        517.8015      0.378   1370.218      0.000     517.061     518.542
# ...

# %%
#stud_res2 = res2.outlier_test()
#print(stud_res2)
#outlier2 = stud_res2[abs(stud_res2['student_resid']) > 3 ].size
#outlier2

# %%
influence2 = res2.get_influence()
cooks2 = influence2.cooks_distance
num2 = np.sum(cooks2[0] > 4/9568)
print("The number of outliers for 'V' model is", num2, '.')
# Out:
# The number of outliers for 'V' model is 423 .

# %%
liregr = LinearRegression()
liregr.fit(X2, y)
pred2 = liregr.predict(X2)

# Create scatter plot
plt.scatter(X2.iloc[:,1].values, y)
plt.plot(X2.iloc[:,1].values, pred2,c='r')
plt.xlabel('V')
plt.ylabel('PE')
plt.show()

# %%
# A linear regression model for AP and PE
X3 = data.loc[:, ['AP']]
y = data.loc[:, ['PE']]
X3 = sm.add_constant(X3)
# Fit and summarize OLS model
mod3 = sm.OLS(y, X3)
res3 = mod3.fit()
print(res3.summary())
#print(res3.pvalues)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.269
# Model:                            OLS   Adj. R-squared:                  0.269
# Method:                 Least Squares   F-statistic:                     3516.
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):               0.00
# Time:                        16:28:03   Log-Likelihood:                -39224.
# No. Observations:                9568   AIC:                         7.845e+04
# Df Residuals:                    9566   BIC:                         7.847e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1055.2610     25.459    -41.449      0.000   -1105.167   -1005.355
# ...

# %%
#stud_res3 = res3.outlier_test()
#print(stud_res3)
#outlier3 = stud_res3[abs(stud_res3['student_resid']) > 3 ].size
#outlier3

# %%
influence3 = res3.get_influence()
cooks3 = influence3.cooks_distance
num3 = np.sum(cooks3[0] > 4/9568)
print("The number of outliers for 'AP' model is", num3, '.')
# Out:
# The number of outliers for 'AP' model is 300 .

# %%
# A linear regression model for RH and PE
X4 = data.loc[:, ['RH']]
y = data.loc[:, ['PE']]
X4 = sm.add_constant(X4)
# Fit and summarize OLS model
mod4 = sm.OLS(y, X4)
res4 = mod4.fit()
print(res4.summary())
#print(res4.pvalues)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.152
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     1714.
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):               0.00
# Time:                        16:28:03   Log-Likelihood:                -39933.
# No. Observations:                9568   AIC:                         7.987e+04
# Df Residuals:                    9566   BIC:                         7.988e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        420.9618      0.823    511.676      0.000     419.349     422.574
# ...

# %%
#stud_res4 = res4.outlier_test()
#print(stud_res4)
#outlier4 = stud_res4[abs(stud_res4['student_resid']) > 3 ].size
#outlier4

# %%
influence4 = res4.get_influence()
cooks4 = influence4.cooks_distance
num4 = np.sum(cooks4[0] > 4/9568)
print("The number of outliers for 'RH' model is", num4, '.')
# Out:
# The number of outliers for 'RH' model is 249 .

# %% [markdown]
# #### I think that there is a statistically significant association between the predictor and the response in all four models. Because all the p-values are less than 0.05. However, R-squared for 'AT' and 'V' models are higher so the model may fit the data well.

# %% [markdown]
# #### I choose the Cook's distance method to find the outliers. The distance D is the normalized change in the fitted response values due to the deletion of an observation, which is useful for identifying outliers in the X values

# %% [markdown]
# #### The threshold is 4/9568 - 4/n, where n is the number of observations.

# %% [markdown]
# #### (d) Fit a multiple regression model to predict the response using all of the predictors.
# Describe your results. For which predictors can we reject the null hypothesis
# H0 : βj = 0?

# %%
X = data.loc[:, ['AT', 'V', 'AP', 'RH']]
y = data.loc[:, ['PE']]
X = sm.add_constant(X)
# Fit and summarize OLS model
mod = sm.OLS(y, X)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):               0.00
# Time:                        16:28:04   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# ...

# %% [markdown]
# #### I think all four predictors can reject the null hypothesis because all the p-values of these predictors are less than 0.05.

# %% [markdown]
# #### (e) How do your results from 1c compare to your results from 1d?
# Create a plot displaying the univariate regression coefficients from 1c on the x-axis, and the
# multiple regression coefficients from 1d on the y-axis. That is, each predictor is
# displayed as a single point in the plot. Its coefficient in a simple linear regression
# model is shown on the x-axis, and its coefficient estimate in the multiple linear
# regression model is shown on the y-axis.

# %%
coef_AT = res1.params.iloc[1]
coef_V = res2.params.iloc[1]
coef_AP = res3.params.iloc[1]
coef_RH = res4.params.iloc[1]
coef_mul = res.params.iloc[1:].to_frame().values
coef_uni = [coef_AT, coef_V, coef_AP, coef_RH]
colors=["red", "green", "blue", "orange"]

# Create a scatter point plot
plt.figure(figsize=(10, 7))
for i in range(len(coef_uni)):
    plt.scatter(coef_uni[i], coef_mul[i], color=colors[i], s = 100)
    plt.text(coef_uni[i], coef_mul[i], (coef_uni[i], float(coef_mul[i])))
plt.xlabel('Simple linear regression model')
plt.ylabel('Multiple linear regression model')
# Out:
# Text(0, 0.5, 'Multiple linear regression model')

# %% [markdown]
# #### For simple linear regression model, AT, V, RH may have a strong correlation. For multiple linear regression model, AT may have a strong correlation. Because the absolute value of coefficient is larger than 0.8.

# %% [markdown]
# #### (f) Is there evidence of nonlinear association between any of the predictors and the response?
# To answer this question, for each predictor X, fit a model of the form
# Y = β0 + β1X + β2X^2 + β3X^3 + e

# %%
# importing libraries for polynomial transform
from sklearn.preprocessing import PolynomialFeatures

X_1 = data.loc[:, ['AT']]
y_ = data.loc[:, ['PE']]

poly = PolynomialFeatures(degree = 3)
X_poly1 = poly.fit_transform(X_1)
X_poly1 = sm.add_constant(X_poly1)
mod = sm.OLS(y_, X_poly1)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                 3.299e+04
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):               0.00
# Time:                        16:28:04   Log-Likelihood:                -29101.
# No. Observations:                9568   AIC:                         5.821e+04
# Df Residuals:                    9564   BIC:                         5.824e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        492.7281      0.673    732.248      0.000     491.409     494.047
# ...

# %%
X_2 = data.loc[:, ['V']]
y_ = data.loc[:, ['PE']]

poly = PolynomialFeatures(degree = 3)
X_poly2 = poly.fit_transform(X_2)
X_poly2 = sm.add_constant(X_poly2)
mod = sm.OLS(y, X_poly2)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.775
# Method:                 Least Squares   F-statistic:                 1.098e+04
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):               0.00
# Time:                        16:28:04   Log-Likelihood:                -33585.
# No. Observations:                9568   AIC:                         6.718e+04
# Df Residuals:                    9564   BIC:                         6.721e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        554.1468      9.151     60.557      0.000     536.209     572.084
# ...

# %%
X_3 = data.loc[:, ['AP']]
y_ = data.loc[:, ['PE']]

poly = PolynomialFeatures(degree = 3)
X_poly3 = poly.fit_transform(X_3)
X_poly3 = sm.add_constant(X_poly3)
mod = sm.OLS(y, X_poly3)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.275
# Model:                            OLS   Adj. R-squared:                  0.275
# Method:                 Least Squares   F-statistic:                     1813.
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):               0.00
# Time:                        16:28:04   Log-Likelihood:                -39184.
# No. Observations:                9568   AIC:                         7.837e+04
# Df Residuals:                    9565   BIC:                         7.840e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0747      0.009      8.415      0.000       0.057       0.092
# ...

# %%
X_4 = data.loc[:, ['RH']]
y_ = data.loc[:, ['PE']]

poly = PolynomialFeatures(degree = 3)
X_poly4 = poly.fit_transform(X_4)
X_poly4 = sm.add_constant(X_poly4)
mod = sm.OLS(y, X_poly4)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.154
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     579.2
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):               0.00
# Time:                        16:28:04   Log-Likelihood:                -39923.
# No. Observations:                9568   AIC:                         7.985e+04
# Df Residuals:                    9564   BIC:                         7.988e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        468.4135     10.545     44.422      0.000     447.744     489.083
# ...

# %% [markdown]
# #### After fitting the model, the p-values of AT, AP and RH are less than 0.05. So they are statistical significant. For the p-value of V, the p-value of x^1 and x^3 are less than 0.05. So there is evidence of nonlinear association between any of the predictors and the response.

# %% [markdown]
# #### (g) Is there evidence of association of interactions of predictors with the response?
# To answer this question, run a full linear regression model with all pairwise interaction
# terms and state whether any interaction terms are statistically significant.

# %%
data1 = data
for i in range(0, 4):
    nam = []
    for j in range (i + 1, 4):
        col1 = str(data1.columns[i])
        col2 = str(data1.columns[j])
        nam = col1 + col2 
        data1[nam] = pd.Series(data1[col1] * data1[col2], name=nam)
data1
# Out:
#          AT      V       AP     RH      PE        ATV        ATAP       ATRH  \
# 0     14.96  41.76  1024.07  73.17  463.26   624.7296  15320.0872  1094.6232
# 1     25.18  62.96  1020.04  59.08  444.37  1585.3328  25684.6072  1487.6344
# 2      5.11  39.40  1012.16  92.14  488.56   201.3340   5172.1376   470.8354
# 3     20.86  57.32  1010.24  76.64  446.48  1195.6952  21073.6064  1598.7104
# 4     10.82  37.50  1009.23  96.62  473.90   405.7500  10919.8686  1045.4284
# ...     ...    ...      ...    ...     ...        ...         ...        ...
# 9563  16.65  49.69  1014.01  91.00  460.03   827.3385  16883.2665  1515.1500
# 9564  13.19  39.18  1023.67  66.78  469.62   516.7842  13502.2073   880.8282
# 9565  31.32  74.33  1012.92  36.48  429.57  2328.0156  31724.6544  1142.5536
# 9566  24.48  69.45  1013.86  62.39  435.74  1700.1360  24819.2928  1527.3072
# 9567  21.60  62.52  1017.23  67.87  453.28  1350.4320  21972.1680  1465.9920
#
#              VAP        VRH        APRH
# ...

# %%
for i in range(0, 4):
    for j in range (i + 1, 4):
        col1 = str(data1.columns[i])
        col2 = str(data1.columns[j])
        pair = col1 + col2 
        X_pair = data1.loc[:, [col1, col2, pair]].values
        y = data1.loc[:, ['PE']].values
        X_pair = sm.add_constant(X_pair)
        # Fit and summarize OLS model
        mod = sm.OLS(y, X_pair)
        res = mod.fit()
        print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.925
# Model:                            OLS   Adj. R-squared:                  0.925
# Method:                 Least Squares   F-statistic:                 3.946e+04
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):               0.00
# Time:                        16:28:04   Log-Likelihood:                -28315.
# No. Observations:                9568   AIC:                         5.664e+04
# Df Residuals:                    9564   BIC:                         5.667e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        530.5331      0.753    704.391      0.000     529.057     532.010
# ...

# %% [markdown]
# #### I think that the pairwise interaction terms ATV, ATRH, VAP, VRH, APRH are statistically significant because all of those p-values are less than 0.05.

# %% [markdown]
# #### (h) Can you improve your model using possible interaction terms or nonlinear associations between the predictors and response?
# Train the regression model on a randomly selected 70% subset of the data with all predictors. Also, run a regression model involving all possible interaction terms and quadratic nonlinearities, and remove insignificant variables using p-values (be careful about interaction terms). Test both models on the remaining points and report your train and test MSEs.

# %%
# The base line model
from sklearn.model_selection import train_test_split
# split into train test sets
X_base = data.loc[:, ['AT', 'V', 'AP', 'RH']]
y = data.loc[:, ['PE']]
X_train, X_test, y_train, y_test = train_test_split(X_base, y, test_size = 0.3, random_state = 1)
X_train = sm.add_constant(X_train)
# Fit and summarize OLS model
mod1 = sm.OLS(y_train, X_train)
res1 = mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     PE   R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                 2.167e+04
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):               0.00
# Time:                        16:28:04   Log-Likelihood:                -19660.
# No. Observations:                6697   AIC:                         3.933e+04
# Df Residuals:                    6692   BIC:                         3.936e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        458.3988     11.562     39.649      0.000     435.734     481.063
# ...

# %%
# a regression model involving all possible interaction terms and quadratic nonlinearities
poly = PolynomialFeatures(degree = 2)
X_no1 = poly.fit_transform(X_1)[:,2]
X_no2 = poly.fit_transform(X_2)[:,2]
X_no3 = poly.fit_transform(X_3)[:,2]
X_no4 = poly.fit_transform(X_4)[:,2]
data1['AT_x2'] = X_no1
data1['V_x2'] = X_no2
data1['AP_x2'] = X_no3
data1['RH_x2'] = X_no4
data1
# Out:
#          AT      V       AP     RH      PE        ATV        ATAP       ATRH  \
# 0     14.96  41.76  1024.07  73.17  463.26   624.7296  15320.0872  1094.6232
# 1     25.18  62.96  1020.04  59.08  444.37  1585.3328  25684.6072  1487.6344
# 2      5.11  39.40  1012.16  92.14  488.56   201.3340   5172.1376   470.8354
# 3     20.86  57.32  1010.24  76.64  446.48  1195.6952  21073.6064  1598.7104
# 4     10.82  37.50  1009.23  96.62  473.90   405.7500  10919.8686  1045.4284
# ...     ...    ...      ...    ...     ...        ...         ...        ...
# 9563  16.65  49.69  1014.01  91.00  460.03   827.3385  16883.2665  1515.1500
# 9564  13.19  39.18  1023.67  66.78  469.62   516.7842  13502.2073   880.8282
# 9565  31.32  74.33  1012.92  36.48  429.57  2328.0156  31724.6544  1142.5536
# 9566  24.48  69.45  1013.86  62.39  435.74  1700.1360  24819.2928  1527.3072
# 9567  21.60  62.52  1017.23  67.87  453.28  1350.4320  21972.1680  1465.9920
#
# ...

# %%
X_all = data1.drop(columns=['PE'])
y = data1.loc[:, ['PE']]
X_train1, X_test1, y_train1, y_test1 = train_test_split(X_all, y, test_size = 0.3, random_state = 1)
X_train1 = sm.add_constant(X_train1)
# Fit and summarize OLS model
mod2 = sm.OLS(y_train1, X_train1)
res2 = mod2.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.385
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     1995.
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):               0.00
# Time:                        16:28:04   Log-Likelihood:                -38397.
# No. Observations:                9568   AIC:                         7.680e+04
# Df Residuals:                    9564   BIC:                         7.683e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1391.0493    132.158    -10.526      0.000   -1650.107   -1131.992
# ...

# %% [markdown]
# #### When the p value is less than 0.05, the variable would be significant. So I would remove ATAP, VAP, VRH, V_x2.

# %%
X_update = data1.drop(columns=['ATAP', 'VAP', 'VRH', 'V_x2', 'PE'])
y = data1.loc[:, ['PE']]
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_update, y, test_size = 0.3, random_state = 1)
X_train2 = sm.add_constant(X_train2)
# Fit and summarize OLS model
mod3 = sm.OLS(y_train2, X_train2)
res3 = mod3.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.385
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     1995.
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):               0.00
# Time:                        16:28:04   Log-Likelihood:                -38397.
# No. Observations:                9568   AIC:                         7.680e+04
# Df Residuals:                    9564   BIC:                         7.683e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1391.0493    132.158    -10.526      0.000   -1650.107   -1131.992
# ...

# %%
# Test the baseline model
from sklearn.metrics import mean_squared_error
X_test = sm.add_constant(X_test)
y_pred_train1 = res1.predict(X_train)
y_pred_test1 = res1.predict(X_test)
print('The MSE of baseline model for train data:', mean_squared_error(y_train, y_pred_train1))
print('The MSE of baseline model for test data:', mean_squared_error(y_test, y_pred_test1))
# Out:
# The MSE of baseline model for train data: 20.766119761450938
# The MSE of baseline model for test data: 20.777478106883994

# %%
# Test the model with whole
X_test2 = sm.add_constant(X_test2)
y_pred_train2 = res3.predict(X_train2)
y_pred_test2 = res3.predict(X_test2)
print('The MSE of whole model for train data:', mean_squared_error(y_train, y_pred_train2))
print('The MSE of whole model for test data:', mean_squared_error(y_test, y_pred_test2))
# Out:
# The MSE of whole model for train data: 18.09323565111237
# The MSE of whole model for test data: 18.263588112345957
# /Users/qy/Applications/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# #### I think we can improve the model using possible interaction terms or nonlinear associations between the predictors and response. When I remove some insignificant variables in the model, the MSE of the updated model will decrease.

# %% [markdown]
# #### (i) KNN Regression:
# i. Perform k-nearest neighbor regression for this dataset using both normalized and raw features. Find the value of k ∈ {1, 2, . . . , 100} that gives you the best fit. Plot the train and test errors in terms of 1/k.

# %%
# Model 1 for raw features
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import accuracy_score
X_base = data.loc[:, ['AT', 'V', 'AP', 'RH']]
y = data.loc[:, ['PE']]
X_train, X_test, y_train, y_test = train_test_split(X_base, y, test_size = 0.3, random_state = 1)

test_error = []
train_error = []
N = []
r = range(1, 101)
for i in r:
    k = i
    N.append(1/k)
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train, y_train)
    # Calculate test error rate
    y_preds1 = knn.predict(X_test)
    test_error.append(mean_squared_error(y_test, y_preds1))
    # Calculate train error rate
    y_preds2 = knn.predict(X_train)
    train_error.append(mean_squared_error(y_train, y_preds2))

# Plot train error rates & test error rate on the map   
plt.figure(figsize=(10, 7))
plt.plot(N,train_error, color='red',label='Training error rate')
plt.plot(N,test_error, color='blue',label='Testing error rate')
plt.xlabel('1/K')
plt.ylabel('Error')
plt.legend()

# %%
# Find out the optimal k value 
k = list(r)[test_error.index(min(test_error))]
print("Minimum error using raw features : ", min(test_error), "at K =", k)
# Out:
# Minimum error using raw features :  15.704821203761764 at K = 5

# %%
# Model 2 for normalized features
from sklearn.preprocessing import MinMaxScaler
# fit scaler on training data
norm = MinMaxScaler().fit(X_train)
# transform training data
X_train_norm = norm.transform(X_train)
# transform testing dataabs
X_test_norm = norm.transform(X_test)

test_error = []
train_error = []
N = []
r = range(1, 101)
for i in r:
    k = i
    N.append(1/k)
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train_norm, y_train)
    # Calculate test error rate
    y_preds1 = knn.predict(X_test_norm)
    test_error.append(mean_squared_error(y_test, y_preds1))
    # Calculate train error rate
    y_preds2 = knn.predict(X_train_norm)
    train_error.append(mean_squared_error(y_train, y_preds2))

# Plot train error rates & test error rate on the map   
plt.figure(figsize=(10, 7))
plt.plot(N,train_error, color='red',label='Training error rate')
plt.plot(N,test_error, color='blue',label='Testing error rate')
plt.xlabel('1/K')
plt.ylabel('Error')
plt.legend()

# %%
# Find out the optimal k value 
k = list(r)[test_error.index(min(test_error))]
print("Minimum error using normalized features: ", min(test_error), "at K =", k)
# Out:
# Minimum error using normalized features:  14.030553676071062 at K = 5

# %% [markdown]
# #### (j) Compare the results of KNN Regression with the linear regression model that has the smallest test error and provide your analysis.

# %% [markdown]
# #### The test MSE of KNN Regression model may have a smaller value than the test MSE of linear regression model which removes some insignificant features.
# The MSE of the linear model for test data: 18.263588112345957,

# %% [markdown]
# The MSE of the KNN Regression model for test data using normalized features: 15.704821203761764 at K = 5

# %% [markdown]
# #### 2. ISLR: 2.4.1

# %% [markdown]
# #### 1. For each of parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.

# %% [markdown]
# #### (a) The sample size n is extremely large, and the number of predictors p is small.

# %% [markdown]
# Better. Because with a large number of samples, the flexible model can better fit the sample data.

# %% [markdown]
# #### (b) The number of predictors p is extremely large, and the number of observations n is small.

# %% [markdown]
# Worse. Because with a small number of observations, they would be more able to overfit by the flexible model.

# %% [markdown]
# #### (c) The relationship between the predictors and response is highly non-linear.

# %% [markdown]
# Better. For the non-linear relationship, a flexible method would fit better.

# %% [markdown]
# #### (d) The variance of the error terms, i.e. σ^2 = Var(ϵ), is extremely high.

# %% [markdown]
# Worse. Due to the high variance of error terms which means a lot of noises, the flexible model would overfit the noise, so we choose the inflexible one.

# %% [markdown]
# #### 7. The table below provides a training data set containing six observations, three predictors, and one qualitative response variable.
# #### Suppose we wish to use this data set to make a prediction for Y when X1 = X2 = X3 = 0 using K-nearest neighbors.

# %% [markdown]
# #### (a) Compute the Euclidean distance between each observation and the test point, X1 = X2 = X3 = 0.

# %%
from scipy.spatial import distance
data = [[0,3,0,'Red'],[2,0,0,'Red'],[0,1,3,'Red'],[0,1,2,'Green'],[-1,0,1,'Green'],[1,1,1,'Red']]

Dis = []
for i in range(6):
    X = data[i][:3]
    Y = [0, 0, 0]
    dist = distance.euclidean(X, Y)
    Dis.append(dist)

data = pd.DataFrame(data, index=[1,2,3,4,5,6], columns=['X1','X2','X3','Y'])
data['Dis'] = Dis
data
# Out:
#    X1  X2  X3      Y       Dis
# 1   0   3   0    Red  3.000000
# 2   2   0   0    Red  2.000000
# 3   0   1   3    Red  3.162278
# 4   0   1   2  Green  2.236068
# 5  -1   0   1  Green  1.414214
# 6   1   1   1    Red  1.732051

# %% [markdown]
# #### (b) What is our prediction with K = 1? Why?

# %% [markdown]
# When K = 1, we should choose point 5

# %% [markdown]
# P(Y=Green|X=x0) = 1

# %% [markdown]
# The prediction with K = 1 is Green. Because K = 1, we should choose one point which has a smallest distance with point[0,0,0]. And the point is point5[-1,0,1]. And the result is Green.

# %% [markdown]
# #### (c) What is our prediction with K = 3? Why?

# %% [markdown]
# When K = 3, we should choose point 2, 5, 6.

# %% [markdown]
# P(Y=Green|X=x0) = 1/3(0+1+0) = 1/3

# %% [markdown]
# P(Y=Red|X=x0) = 1/3(1+0+1) = 2/3

# %% [markdown]
# So the prediction is Red.

# %% [markdown]
# #### (d) If the Bayes decision boundary in this problem is highly nonlinear, then would we expect the best value for K to be large or small? Why?

# %% [markdown]
# When the K is large, the boundary will be linear. So for the highly nonlinear boundary, we should choose a small K value.

# %%
conda install -c conda-forge pipreqs
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip freeze > requirements.txt
# Out:
# WARNING: Ignoring invalid distribution -nsorflow (/Users/qy/Applications/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution - (/Users/qy/Applications/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/Users/qy/Applications/anaconda3/lib/python3.8/site-packages)
# Note: you may need to restart the kernel to use updated packages.
